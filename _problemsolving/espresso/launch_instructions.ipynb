# %% [markdown]
# # Build
# https://espressomd.github.io/doc/installation.html#quick-installation
#
# cd build
# rm CMakeCache.txt
#
# cmake .. -DEXTERNAL_CUDA_COMPUTE_CAPABILITY=6.1 -DCMAKE_BUILD_TYPE=Release -DPYTHON_EXECUTABLE=$(which python)
#
# make -j$(nproc)
#
#
# # Run Python Scripts (Espresso already built)
# ./pypresso /home/main/Documents/Career/1_Studium/Semester/9_WS_25/BArbeit/bsc_hemminger/elcic/energy/dual_plates/neutral/dipole/dual_plate_zshift.py
