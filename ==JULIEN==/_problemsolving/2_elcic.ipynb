# %%
ACTION_DESCRIPTION, REWARD_ESTIMATE, CHILDREN, REFINEMENT = []
NO, MAYBE, YES_TODOOOOOOO, YES_DONE = []
f"""

* implement ELCIC in "get_elc_energy": {YES_TODOOOOOOO}
    * how do i add dielectric interfaces using espresso.System, etc?
        * cant use P3M anymore (" The algorithm does not work in combination with the electrostatic extension Dielectric interfaces with the ICC* algorithm.")
    
    * what problem types do i examine?
        * same tests & plots as with regular elc?

    
    * analytical solution?
        * are there analytical solutions?
        
        * solvers in espresso (mmm2dic?)
            * "espressomd.electrostatic_extensions.ICC"?
"""
