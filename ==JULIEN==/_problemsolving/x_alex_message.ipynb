# %% [markdown]
# Kann man auch mit dielectic interfaces, wie beim regular ELC, einfach den Slab riesig (z.b. Lx=Ly=500, Lz=10) machen, um ein "No Periodicity" System zu approximieren? Ich hab in den Papern keinen klaren Grund, warum das nicht funktionieren würde, gefunden. Aber ich will mal sicher gehen.
# Wenn das klappt, würde ich einfach das für die "Single Interface (No Periodicity)" und "Dielectric Sandwich (No Periodicity)" Tests nutzen.
